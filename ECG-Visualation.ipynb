# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline

# %%
current_dir = os.getcwd()

trainpath = current_dir+"/data/mitbih_train.csv"
data = pd.read_csv(trainpath,header=None,usecols=range(188))
data.columns
X_train = data[[i for i in range(0,187)]]
y_train = pd.read_csv(trainpath,header=None,usecols=[187]).iloc[:,0]
x_train.shape
# Out:
# (87554, 187)

# %%
def plot(x_data, y_data, classes=range(5), plots_per_class=10):

    f, ax = plt.subplots(5, sharex=True, sharey=True, figsize=(10,10))
    for i in classes:
        for j in range(plots_per_class):
            ax[i].set_title("class{}".format(i))
            ax[i].plot(x_data[y_data == i].iloc[j,:], color="blue", alpha=.5)
            
plot(x_train, y_train)

# %%
class_0_data = data[data[187] == 0 ]
class_1_data = data[data[187] == 1 ]
class_2_data = data[data[187] == 2 ]
class_3_data = data[data[187] == 3 ]
class_4_data = data[data[187] == 4 ]

# %%
_, (ax1,ax2) = plt.subplots(2,1, figsize=(16,9))

ax1.plot(class_0_data.loc[:,:186].mean(), label='noraml')
ax1.plot(class_1_data.loc[:,:186].mean(), label='abnoraml')
ax1.set_title("Mean of the data points for heart data between class 0 and class 1")
ax1.legend()

ax2.plot(class_0_data.loc[:,:186].std(), label='noraml')
ax2.plot(class_1_data.loc[:,:186].std(), label='abnoraml')
ax2.legend()
ax2.set_title("STD for heart data between class 0 and class 1")
# Out:
# Text(0.5, 1.0, 'STD for heart data between class 0 and class 1')

# %%
_, (ax1,ax2) = plt.subplots(2,1, figsize=(16,9))

ax1.plot(class_0_data.loc[:,:186].mean(), label='noraml')
ax1.plot(class_2_data.loc[:,:186].mean(), label='abnoraml')
ax1.set_title("Mean of the data points for heart data between class 0 and class 2")
ax1.legend()

ax2.plot(class_0_data.loc[:,:186].std(), label='noraml')
ax2.plot(class_2_data.loc[:,:186].std(), label='abnoraml')
ax2.legend()
ax2.set_title("STD for heart data between class 0 and class 2")
# Out:
# Text(0.5, 1.0, 'STD for heart data between class 0 and class 2')

# %%
_, (ax1,ax2) = plt.subplots(2,1, figsize=(16,9))

ax1.plot(class_0_data.loc[:,:186].mean(), label='noraml')
ax1.plot(class_3_data.loc[:,:186].mean(), label='abnoraml')
ax1.set_title("Mean of the data points for heart data between class 0 and class 3")
ax1.legend()

ax2.plot(class_0_data.loc[:,:186].std(), label='noraml')
ax2.plot(class_3_data.loc[:,:186].std(), label='abnoraml')
ax2.legend()
ax2.set_title("STD for heart data between class 0 and class 3")
# Out:
# Text(0.5, 1.0, 'STD for heart data between class 0 and class 3')

# %%
_, (ax1,ax2) = plt.subplots(2,1, figsize=(16,9))

ax1.plot(class_0_data.loc[:,:186].mean(), label='noraml')
ax1.plot(class_4_data.loc[:,:186].mean(), label='abnoraml')
ax1.set_title("Mean of the data points for heart data between class 0 and class 4")
ax1.legend()

ax2.plot(class_0_data.loc[:,:186].std(), label='noraml')
ax2.plot(class_4_data.loc[:,:186].std(), label='abnoraml')
ax2.legend()
ax2.set_title("STD for heart data between class 0 and class 4")
# Out:
# Text(0.5, 1.0, 'STD for heart data between class 0 and class 4')
